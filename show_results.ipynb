# %% [markdown]
# <a href="https://colab.research.google.com/github/davidfague/parallel-neuron/blob/main/show_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/davidfague/parallel-neuron.git
# Out:
# Cloning into 'parallel-neuron'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 95 (delta 50), reused 50 (delta 23), pack-reused 0 (from 0)
# Receiving objects: 100% (95/95), 31.84 KiB | 3.54 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
import pandas as pd

# %%
# %cd parallel-neuron/
# Out:
# /content/parallel-neuron

# %% [markdown]
# ## Matrix Multiplication Results

# %%
pd.read_csv('matrix_multiplication_results/combined_csv.csv')
# Out:
#      NxN         Time  Parallelization      Location  mpi_size
# 0     10     0.000643             True      cloudlab         4
# 1     10     0.001169             True  Google Colab         1
# 2     10     0.002362            False  Google Colab         1
# 3     10     0.006039            False            pc         2
# 4     10     0.039112             True            pc         2
# 5    100     0.218337             True      cloudlab         4
# 6    100     0.966473             True  Google Colab         1
# 7    100     1.460237             True            pc         2
# 8    100     2.370361            False            pc         2
# 9    100     2.883406            False  Google Colab         1
# 10   500    26.359883             True      cloudlab         4
# 11   500   136.740910             True  Google Colab         1
# 12   500   141.062555            False  Google Colab         1
# 13   500   170.458516             True            pc         2
# ...

# %% [markdown]
# My PC(chromebook) took longer than Google Colab even when running on multiple cores.
#
#
# I wasn't able to utilize more workers in Google Colab, probably needing to change the processing unit.
#
# CloudLab works very well.

# %% [markdown]
# ## Ring Neuronal Network Results

# %%
pd.read_csv('neuron_ring_results/combined_csv.csv')
# Out:
#        Time  Total cells  avg_num_cells_per_worker  Location  parallel workers
# 0  2.624890         1000                    1000.0  cloudlab                 1
# 1  1.479734         1000                     500.0  cloudlab                 2
# 2  0.995920         1000                     250.0  cloudlab                 4
# 3  0.825153         1000                     125.0  cloudlab                 8
# 4  0.800559         1000                      62.5  cloudlab                16

# %% [markdown]
# results are as expected! Maybe I should'be tried increase the total cells even more.
